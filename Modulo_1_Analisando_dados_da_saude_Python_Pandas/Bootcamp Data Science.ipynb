# %% [markdown]
# # Caderno de exploração dos dados DATASUS de 2008 em diante

# %%
# importando as bibliotecas necessárias
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# # Aula 01

# %%
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe7 in position 57: invalid continuation byte
## resolução: encoding = 'ISO-8859-1'

# %%
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 5, saw 154
## resolução: skiprows = 3
### descartando as 3 primeiras linhas

# %% [markdown]
# **encoding**: escolhe o encoding para ser utilizado na leitura e escrita
#
# **skiprows**: descarta as primeiras linhas indicadas pelo valor passado
#
# **sep**: escolhe o delimitador a ser utilizado
#
# **skipfooter**: descarta as ultimas linhas indicadas pelo valor passado
#
# **thousands**: escolhe o separador dos milhares
#
# **decimal**: escolha o separador dos decimais

# %%
# carregando a base de dados
dados = pd.read_csv('A160324189_28_143_208.csv', 
                    encoding = 'ISO-8859-1', 
                    skiprows= 3, 
                    sep = ';', 
                    skipfooter= 12, 
                    thousands= '.', 
                    decimal= ',')
# Out:
# /home/heliorlz/anaconda3/envs/alura/lib/python3.7/site-packages/ipykernel_launcher.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.

# %%
# visualizando os 5 primeiros registros
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...     2019/Dez     2020/Jan     2020/Fev  \
# 0        -        -        -  ...   8660753.05   8326416.32   8413784.42
# 1        -        -        -  ...   2959569.09   3261123.88   2981264.22
# 2        -        -        -  ...  14923380.22  15939561.23  15138110.70
# 3        -        -        -  ...   2889969.87   3084561.08   2967159.04
# 4        -        -        -  ...  35222625.80  37009819.17  34635702.52
#
#       2020/Mar     2020/Abr     2020/Mai     2020/Jun     2020/Jul  \
# 0   7174312.31   7423678.64   8581195.13   9193593.76   7407388.24
# 1   2859102.06   2472063.08   2383895.48   2199920.70   1163813.08
# 2  14773739.41  16330913.81  19441150.53  17509334.66  13358514.02
# 3   2813954.05   2304961.42   2910776.44   3216466.51   2739498.41
# 4  34749098.46  28714969.96  41248502.78  35396030.78  27618727.51
#
#       2020/Ago         Total
# 0   3556381.57  9.291297e+08
# 1            -  4.206680e+08
# 2   4726485.73  1.771655e+09
# 3   1524478.04  3.050109e+08
# 4  11559714.54  4.437116e+09
#
# [5 rows x 280 columns]

# %%
# visualizando os 5 ultimos registros
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...     2019/Dez     2020/Jan  \
# 22        -        -        -        -  ...  88720873.59  97474362.62
# 23        -        -        -        -  ...  17844511.04  18653296.92
# 24        -        -        -        -  ...  13827706.20  15445693.74
# 25        -        -        -        -  ...  34050298.55  36312121.02
# 26        -        -        -        -  ...  19207148.01  20429067.27
#
#        2020/Fev     2020/Mar     2020/Abr     2020/Mai     2020/Jun  \
# 22  85451646.35  84651396.59  76294596.96  86076113.42  89019478.82
# 23  17769247.00  17357008.80  15652772.51  16703851.10  15838659.34
# 24  14431171.87  14444207.60  11943713.53  13981483.29  14585009.42
# 25  34158023.81  34558308.52  27499307.93  31870107.62  34437633.20
# 26  18219172.96  19405446.88  18123899.78  21437430.22  23479773.03
#
#        2020/Jul     2020/Ago         Total
# 22  78929703.81  28349257.38  1.195865e+10
# 23  12508717.35   4059220.22  2.172158e+09
# 24  13083151.70   6174224.99  2.036924e+09
# 25  33499284.38  20242641.73  4.657349e+09
# 26  22233542.26  12044848.02  2.429933e+09
#
# [5 rows x 280 columns]

# %%
# formnatando a saida dos numeros float
pd.options.display.float_format = '{:.2f}'.format

# %%
# gasto médio por Estado em cada mês
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
# acessando uma única coluna do nosso DataFrame -> retornando uma Series
dados['2008/Ago']
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42487939.51
# 19   179898070.22
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21041071.33
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
# gasto médio do mês de agosto do ano de 2008
dados['2008/Ago'].mean()
# Out:
# 26636409.89222223

# %%
# criando um gráfico básico para visualizar os gastos por Unidade da Federação no mês de agosto de 2008 
dados.plot(x = 'Unidade da Federação', y = '2008/Ago')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
# melhorando o gráfico anterior
## alterando o tipo do gráfico: kind = 'bar'
### aumentando a área da figura: figsize = (14, 8)
dados.plot(x = 'Unidade da Federação', y = '2008/Ago', kind = 'bar', figsize = (14, 8))
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
# melhorando ainda mais o gráfico anterior
## utilizando a biblioteca matplotlib conseguimos acesso aos eixos
ax = dados.plot(x = 'Unidade da Federação', y = '2008/Ago', kind = 'bar', figsize = (14, 8))

# formatando a saida da label dos valores de gastos por Unidade da Federação
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title('Valor por Unidade da Federação', fontsize = 20)

plt.show()

# %% [markdown]
# ### Desafio 01: escolher um título mais descritivo, que passa a mensagem adequada.

# %%
# gerando um gráfico que contém os gastos por Unidade da Federação no mês de agosto do ano de 2008
ax = dados.plot(x = 'Unidade da Federação', y = '2008/Ago', kind = 'bar', figsize = (14, 8))

# formatando a saida da label dos valores de gastos por Unidade da Federação
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title('Gastos de cada Unidade da Federação no mês de agosto do ano de 2008', fontsize = 20)

plt.show()

# %% [markdown]
# ### Desafio 02: faça a mesma análise pro mês mais recente.

# %%
# ao nalisarmos o mês mais recente, descobrimos que o Estado do Acre continha informação não válida
## para regularização momentanea, alteramos seu valor de '-' para 0 e seu tipo de dados para float
### seria o caso de descobrir o porquê do dado estar preenchido desta forma
dados['2020/Ago'] = dados['2020/Ago'].replace('-', 0)
dados['2020/Ago'] = dados['2020/Ago'].astype(float)

# %%
dados['2020/Ago']
# Out:
# 0      3556381.57
# 1            0.00
# 2      4726485.73
# 3      1524478.04
# 4     11559714.54
# 5       834187.31
# 6      2453362.74
# 7     10916718.78
# 8      7926321.69
# 9     14559529.59
# 10     8080160.97
# 11     8585226.08
# 12    33544876.14
# 13     6487947.82
# 14     1742127.72
# 15    26023558.53
# 16    57473699.06
# 17    10824255.26
# 18    36264322.65
# 19   140414944.95
# 20    41542401.16
# 21    16991236.43
# 22    28349257.38
# 23     4059220.22
# 24     6174224.99
# 25    20242641.73
# 26    12044848.02
# Name: 2020/Ago, dtype: float64

# %%
# gerando um gráfico que contém os gastos por Unidade da Federação no mês de agosto do ano de 2020
ax = dados.plot(x = 'Unidade da Federação', y = '2020/Ago', kind = 'bar', figsize = (14, 8))

# formatando a saida da label dos valores de gastos por Unidade da Federação
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title('Gastos de cada Unidade da Federação no mês de agosto do ano de 2020', fontsize = 20)

plt.show()

# %% [markdown]
# # Aula 02

# %%
# fatiando nosso DataFrame em duas colunas selecionadas
dados[['2008/Ago', '2008/Set']].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
# selecionando apenas as colunas que contem dados, o metodo mean desconsidera colunas com dados vazios
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, 'Unidade da Federação')
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  '2020/Ago',
#  'Total']

# %%
# retornando DataFrame com apenas as colunas selecioandas anteriormente
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2019/Dez  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ...  8660753.05
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  2959569.09
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 14923380.22
# 3   808448.39   771687.83   876091.18   896952.53  ...  2889969.87
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 35222625.80
#
#      2020/Jan    2020/Fev    2020/Mar    2020/Abr    2020/Mai    2020/Jun  \
# 0  8326416.32  8413784.42  7174312.31  7423678.64  8581195.13  9193593.76
# 1  3261123.88  2981264.22  2859102.06  2472063.08  2383895.48  2199920.70
# 2 15939561.23 15138110.70 14773739.41 16330913.81 19441150.53 17509334.66
# 3  3084561.08  2967159.04  2813954.05  2304961.42  2910776.44  3216466.51
# 4 37009819.17 34635702.52 34749098.46 28714969.96 41248502.78 35396030.78
#
#      2020/Jul    2020/Ago         Total
# 0  7407388.24  3556381.57  929129659.72
# 1  1163813.08        0.00  420668039.63
# 2 13358514.02  4726485.73 1771654871.23
# 3  2739498.41  1524478.04  305010883.18
# 4 27618727.51 11559714.54 4437115730.71
#
# [5 rows x 159 columns]

# %%
# atribuindo a Unidade da Federação como Index
usaveis.set_index('Unidade da Federação', inplace=True)

# %%
# visualizando a coluna Agosto de 2019
usaveis['2019/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
# visualizando os valores encontrados na linha 12 Acre
usaveis.loc['12 Acre']
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# 2020/Ago           0.00
# Total      420668039.63
# Name: 12 Acre, Length: 158, dtype: float64

# %%
# plotando o gráfico dos Estados pelo Mês/Ano, veriricamos com a coluna Total está desconfigurando 
usaveis.T.plot(figsize = (14, 8))
# Out:
# <AxesSubplot:>

# %%
# dropando a coluna Total
usaveis = usaveis.drop('Total', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-cb9872b5eed1> in <module>
# ----> 1 usaveis = usaveis.drop('Total', axis = 1)
#       2 usaveis.tail()
#
# ~/anaconda3/envs/alura/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4167             level=level,
#    4168             inplace=inplace,
# -> 4169             errors=errors,
#    4170         )
#    4171
#
# ~/anaconda3/envs/alura/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# -> 3884                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3885
#    3886         if inplace:
#
# ~/anaconda3/envs/alura/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3916                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3917             else:
# -> 3918                 new_axis = axis.drop(labels, errors=errors)
#    3919             result = self.reindex(**{axis_name: new_axis})
#    3920
#
# ~/anaconda3/envs/alura/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5276         if mask.any():
#    5277             if errors != "ignore":
# -> 5278                 raise KeyError(f"{labels[mask]} not found in axis")
#    5279             indexer = indexer[~mask]
#    5280         return self.delete(indexer)
#
# KeyError: "['Total'] not found in axis"

# %%
# verificando se realmente foi dropada
usaveis.tail()
# Out:
#                         2007/Ago   2007/Set   2007/Out    2007/Nov  \
# Unidade da Federação
# 43 Rio Grande do Sul  1049252.33 3182913.14 8571312.11 16592432.80
# 50 Mato Grosso do Sul  199556.12  573675.41 1069816.66  1995899.52
# 51 Mato Grosso          63562.50  232444.62  927219.59  1740439.60
# 52 Goiás               179395.82  418053.58 1198730.25  2712117.54
# 53 Distrito Federal    191951.47  769966.25 2165619.56  3813256.48
#
#                          2007/Dez    2008/Jan    2008/Fev    2008/Mar  \
# Unidade da Federação
# 43 Rio Grande do Sul  30134255.70 51064610.03 45897704.82 52928695.92
# 50 Mato Grosso do Sul  4277979.14  8301006.10  8279288.79  9793888.78
# 51 Mato Grosso         5394225.43  8213438.64  7929894.93  9416367.68
# 52 Goiás               9293914.78 74063828.22 18149374.27 20992213.03
# 53 Distrito Federal    7121965.42 10561085.46 10215956.80 11627918.26
#
#                          2008/Abr    2008/Mai  ...    2019/Nov    2019/Dez  \
# Unidade da Federação                           ...
# 43 Rio Grande do Sul  51972416.77 51679350.79  ... 90971809.22 88720873.59
# 50 Mato Grosso do Sul  8997542.75  9842108.59  ... 18316480.80 17844511.04
# 51 Mato Grosso         9390588.03  9378197.25  ... 15097362.41 13827706.20
# 52 Goiás              21049477.30 19162546.79  ... 36234132.35 34050298.55
# 53 Distrito Federal   11922015.36 11900817.00  ... 19617400.92 19207148.01
#
#                          2020/Jan    2020/Fev    2020/Mar    2020/Abr  \
# Unidade da Federação
# 43 Rio Grande do Sul  97474362.62 85451646.35 84651396.59 76294596.96
# 50 Mato Grosso do Sul 18653296.92 17769247.00 17357008.80 15652772.51
# 51 Mato Grosso        15445693.74 14431171.87 14444207.60 11943713.53
# 52 Goiás              36312121.02 34158023.81 34558308.52 27499307.93
# 53 Distrito Federal   20429067.27 18219172.96 19405446.88 18123899.78
#
#                          2020/Mai    2020/Jun    2020/Jul    2020/Ago
# Unidade da Federação
# 43 Rio Grande do Sul  86076113.42 89019478.82 78929703.81 28349257.38
# 50 Mato Grosso do Sul 16703851.10 15838659.34 12508717.35  4059220.22
# 51 Mato Grosso        13981483.29 14585009.42 13083151.70  6174224.99
# 52 Goiás              31870107.62 34437633.20 33499284.38 20242641.73
# 53 Distrito Federal   21437430.22 23479773.03 22233542.26 12044848.02
#
# [5 rows x 157 columns]

# %%
# plotando o gráfico dos Estados pelo Mês/Ano
usaveis.T.plot(figsize = (14, 8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Desafio 01: reposicionar a legenda do gráfico anterior.

# %%
# plotando o gráfico dos Estados pelo Mês/Ano, formatando a caixa da legenda
ax = usaveis.T.plot(figsize = (14, 8))

plt.legend(loc='right', bbox_to_anchor=(1.22, 0.5))

# formatando a saida da label dos valores de gastos por Unidade da Federação
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title('Gastos de cada Unidade da Federação a partir de Agosto de 2007', fontsize = 20)

plt.show()

# %% [markdown]
# ### Desafio 02: Plotar o mesmo gráfico anterior, selecionando apenas 5 Estados.

# %%
# selecionando os 5 Estados para serem plotados
usaveis_cinco_estados = usaveis.loc[['35 São Paulo', 
           '33 Rio de Janeiro', 
           '31 Minas Gerais', 
           '53 Distrito Federal', 
           '23 Ceará']]

# %%
# plotando o gráfico anterior visualizando apenas os 5 Estados selecionados
ax = usaveis_cinco_estados.T.plot(figsize = (16, 8))

# formatando a saida da label dos valores de gastos por Unidade da Federação
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title('Gastos de cada Unidade da Federação desde de Agosto de 2007 por mês, observando pelos 5 Estados selecionados', fontsize = 16)

plt.show()
